# %% [markdown]
# # Prototype for Trakt.tv

# %%
# setup
import requests
import json

# %% [markdown]
# Endpoint: Trending shows

# %%
header = {'Content-Type':'application/json', 
          'trakt-api-version':'2', 
          'trakt-api-key':'5d80e38e554f65169841914d27f60442ffc3939805424ad026a17c97e94bf665'}


con = json.loads(requests.get('https://api.trakt.tv/shows/trending', headers = header).text)
con
# Out:
# [{'watchers': 44,
#   'show': {'title': '9-1-1',
#    'year': 2018,
#    'ids': {'trakt': 125308,
#     'slug': '9-1-1-2018',
#     'tvdb': 337907,
#     'imdb': 'tt7235466',
#     'tmdb': 75219,
#     'tvrage': None}}},
#  {'watchers': 36,
#   'show': {'title': 'The Good Doctor',
#    'year': 2017,
#    'ids': {'trakt': 119095,
#     'slug': 'the-good-doctor',
#     'tvdb': 328634,
#     'imdb': 'tt6470478',
#     'tmdb': 71712,
#     'tvrage': None}}},
#  {'watchers': 36,
#   'show': {'title': 'Snowpiercer',
#    'year': 2020,
#    'ids': {'trakt': 136863,
#     'slug': 'snowpiercer',
#     'tvdb': 364928,
#     'imdb': 'tt6156584',
#     'tmdb': 79680,
#     'tvrage': None}}},
#  {'watchers': 36,
#   'show': {'title': '9-1-1: Lone Star',
#    'year': 2020,
#    'ids': {'trakt': 147906,
#     'slug': '9-1-1-lone-star',
#     'tvdb': 364080,
#     'imdb': 'tt10323338',
#     'tmdb': 89393,
#     'tvrage': None}}},
#  {'watchers': 32,
#   'show': {'title': 'The Simpsons',
# ...

# %% [markdown]
# Endpoint: watched

# %%
header = {'Content-Type':'application/json', 
          'trakt-api-version':'2', 
          'trakt-api-key':'5d80e38e554f65169841914d27f60442ffc3939805424ad026a17c97e94bf665'}

con = json.loads(requests.get('https://api.trakt.tv/shows/watched/daily', headers = header).text)

for o in con: print(o['show']['title'])
    
con
# Out:
# The Blacklist
# WandaVision
# The Equalizer
# American Gods
# The Rookie
# Batwoman
# NCIS: Los Angeles
# Attack on Titan
# Last Week Tonight with John Oliver
# Saturday Night Live
# [{'watcher_count': 5682,
#   'play_count': 21486,
#   'collected_count': 25736,
#   'collector_count': 930,
#   'show': {'title': 'The Blacklist',
#    'year': 2013,
#    'ids': {'trakt': 46676,
#     'slug': 'the-blacklist',
#     'tvdb': 266189,
#     'imdb': 'tt2741602',
#     'tmdb': 46952,
#     'tvrage': 35048}}},
#  {'watcher_count': 5042,
#   'play_count': 17076,
#   'collected_count': 3977,
#   'collector_count': 795,
#   'show': {'title': 'WandaVision',
#    'year': 2021,
#    'ids': {'trakt': 146518,
#     'slug': 'wandavision',
#     'tvdb': 362392,
#     'imdb': 'tt9140560',
#     'tmdb': 85271,
#     'tvrage': None}}},
#  {'watcher_count': 3901,
#   'play_count': 6165,
#   'collected_count': 2037,
#   'collector_count': 1560,
#   'show': {'title': 'The Equalizer',
#    'year': 2021,
# ...
